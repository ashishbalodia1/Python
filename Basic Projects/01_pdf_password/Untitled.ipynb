# %%
# !pip install pyPDF2

# %%
# !pip install PyPDF2

# %%
from PyPDF2 import PdfReader, PdfWriter

# %%
# print(PyPDF2.__version__)

# %%
# Open the current PDF
file_pdf =  PdfReader("resume.pdf")
out_pdf = PdfWriter()

# %%
file_pdf

# %%
# Number of Pages in pdf
print(len(file_pdf.pages))
# Out:
# 1

# %%
for i in file_pdf.pages:
    page_details = file_pdf.getPage(i)

    # Add to the output page
    out_pdg.addPage(page_details)
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[9], line 2
#       1 for i in file_pdf.pages:
# ----> 2     page_details = file_pdf.getPage(i)
#       4     # Add to the output page
#       5     out_pdg.addPage(page_details)
#
# File ~\anaconda33\envs\pyforest_env\Lib\site-packages\PyPDF2\_reader.py:476, in PdfReader.getPage(self, pageNumber)
#     470 def getPage(self, pageNumber: int) -> PageObject:  # pragma: no cover
#     471     """
#     472     .. deprecated:: 1.28.0
#     473
#     474         Use :code:`reader.pages[page_number]` instead.
#     475     """
# --> 476     deprecation_with_replacement(
#     477         "reader.getPage(pageNumber)", "reader.pages[page_number]", "3.0.0"
#     478     )
#     479     return self._get_page(pageNumber)
#
# ...
