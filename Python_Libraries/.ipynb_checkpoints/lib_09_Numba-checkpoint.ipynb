# %% [markdown]
# ## Quick Guide to Numba
#
# Namba is a just in time(JIT) compiler for pytohn that works best in the code that uses NumPy arrays and functions and loops.
#
# Use through collection of decorators that can be applied to functions to instruct Numba to comiple them.

# %%
# !pip install numba
# Out:
# Requirement already satisfied: numba in c:\users\ashis\anaconda33\lib\site-packages (0.61.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\ashis\anaconda33\lib\site-packages (from numba) (0.44.0)
# Requirement already satisfied: numpy<2.2,>=1.24 in c:\users\ashis\anaconda33\lib\site-packages (from numba) (2.1.3)
