# %%
import numpy as np
import pandas as pd

# %%
# Creating a Series
series = s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
series
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# Creating a DataFrame by passing numpy array
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %% [markdown]
# ## Viewing Data

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.885893  0.533066 -0.516280 -2.769899
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653
# 2013-01-04 -0.271781  0.861993 -1.076835  1.035000
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423
# 2013-01-06 -0.603570 -0.465219 -2.304896 -0.003780

# %%
df.head(5)
# Out:
#                    A         B         C         D
# 2013-01-01 -0.885893  0.533066 -0.516280 -2.769899
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653
# 2013-01-04 -0.271781  0.861993 -1.076835  1.035000
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423

# %%
df.tail(5)
# Out:
#                    A         B         C         D
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653
# 2013-01-04 -0.271781  0.861993 -1.076835  1.035000
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423
# 2013-01-06 -0.603570 -0.465219 -2.304896 -0.003780

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# To return the DataFrame into numpy
df.to_numpy()
# Out:
# array([[-0.88589346,  0.53306622, -0.51627959, -2.7698986 ],
#        [ 0.63604189, -0.52026205, -0.21024313, -1.03084143],
#        [-0.59908394, -3.22244369, -0.5562102 ,  0.34365272],
#        [-0.27178104,  0.86199274, -1.07683522,  1.03500016],
#        [-1.38335297,  1.06887859,  0.27100298,  0.14342305],
#        [-0.60357034, -0.46521915, -2.30489577, -0.00378003]])

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
# Statistic summary of data
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.517940 -0.290665 -0.732243 -0.380407
# std    0.676833  1.583289  0.888661  1.347340
# min   -1.383353 -3.222444 -2.304896 -2.769899
# 25%   -0.815313 -0.506501 -0.946679 -0.774076
# 50%   -0.601327  0.033924 -0.536245  0.069822
# 75%   -0.353607  0.779761 -0.286752  0.293595
# max    0.636042  1.068879  0.271003  1.035000

# %%
# Transporsing the data
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.885893    0.636042   -0.599084   -0.271781   -1.383353   -0.603570
# B    0.533066   -0.520262   -3.222444    0.861993    1.068879   -0.465219
# C   -0.516280   -0.210243   -0.556210   -1.076835    0.271003   -2.304896
# D   -2.769899   -1.030841    0.343653    1.035000    0.143423   -0.003780

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -2.769899 -0.516280  0.533066 -0.885893
# 2013-01-02 -1.030841 -0.210243 -0.520262  0.636042
# 2013-01-03  0.343653 -0.556210 -3.222444 -0.599084
# 2013-01-04  1.035000 -1.076835  0.861993 -0.271781
# 2013-01-05  0.143423  0.271003  1.068879 -1.383353
# 2013-01-06 -0.003780 -2.304896 -0.465219 -0.603570

# %%
# Sort by an axis
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -2.769899 -0.516280  0.533066 -0.885893
# 2013-01-02 -1.030841 -0.210243 -0.520262  0.636042
# 2013-01-03  0.343653 -0.556210 -3.222444 -0.599084
# 2013-01-04  1.035000 -1.076835  0.861993 -0.271781
# 2013-01-05  0.143423  0.271003  1.068879 -1.383353
# 2013-01-06 -0.003780 -2.304896 -0.465219 -0.603570

# %%
# Sort by values
df.sort_values(by = 'B')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841
# 2013-01-06 -0.603570 -0.465219 -2.304896 -0.003780
# 2013-01-01 -0.885893  0.533066 -0.516280 -2.769899
# 2013-01-04 -0.271781  0.861993 -1.076835  1.035000
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423

# %% [markdown]
# ## Selection

# %% [markdown]
# #### Selection by Getitem([])

# %%
# passing a single label selects a column and yields a Series:
df['A']
# Out:
# 2013-01-01   -0.885893
# 2013-01-02    0.636042
# 2013-01-03   -0.599084
# 2013-01-04   -0.271781
# 2013-01-05   -1.383353
# 2013-01-06   -0.603570
# Freq: D, Name: A, dtype: float64

# %%
df.A
# Out:
# 2013-01-01   -0.885893
# 2013-01-02    0.636042
# 2013-01-03   -0.599084
# 2013-01-04   -0.271781
# 2013-01-05   -1.383353
# 2013-01-06   -0.603570
# Freq: D, Name: A, dtype: float64

# %%
#  Passing a list of column labels selects multiple columns
df[['B','A']]
# Out:
#                    B         A
# 2013-01-01  0.533066 -0.885893
# 2013-01-02 -0.520262  0.636042
# 2013-01-03 -3.222444 -0.599084
# 2013-01-04  0.861993 -0.271781
# 2013-01-05  1.068879 -1.383353
# 2013-01-06 -0.465219 -0.603570

# %%
# passing a slice : selects matching rows:

df[1:3]
# Out:
#                    A         B         C         D
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653

# %% [markdown]
# #### Selection by Label

# %%
# using .loc() and .iloc()

# %%
# Selecting a row matching a labeL
df.loc[dates[0]]
# Out:
# A   -0.885893
# B    0.533066
# C   -0.516280
# D   -2.769899
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
# Selecting all rows (:) with a select column labels
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01 -0.885893  0.533066
# 2013-01-02  0.636042 -0.520262
# 2013-01-03 -0.599084 -3.222444
# 2013-01-04 -0.271781  0.861993
# 2013-01-05 -1.383353  1.068879
# 2013-01-06 -0.603570 -0.465219

# %%
# For label slicing, both endpoints are included:
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  0.636042 -0.520262
# 2013-01-03 -0.599084 -3.222444
# 2013-01-04 -0.271781  0.861993

# %%
# Selecting a single row and column label returns a scalar:
df.loc[dates[0], "A"]
# Out:
# np.float64(-0.8858934561181924)

# %%
# For getting fast access to a scalar
df.at[dates[0], 'A']
# Out:
# np.float64(-0.8858934561181924)

# %% [markdown]
# #### Selection by position

# %%
df.iloc[3]
# Out:
# A   -0.271781
# B    0.861993
# C   -1.076835
# D    1.035000
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
# Integer Slicing 
df.iloc[3:5, 2:4]
# Out:
#                    C         D
# 2013-01-04 -1.076835  1.035000
# 2013-01-05  0.271003  0.143423

# %%
# Lists of integer position locations
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2013-01-02  0.636042 -0.210243
# 2013-01-03 -0.599084 -0.556210
# 2013-01-05 -1.383353  0.271003

# %%
# For slicing rows explicitly
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653

# %%
# For slicing columns explicitly
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.533066 -0.516280
# 2013-01-02 -0.520262 -0.210243
# 2013-01-03 -3.222444 -0.556210
# 2013-01-04  0.861993 -1.076835
# 2013-01-05  1.068879  0.271003
# 2013-01-06 -0.465219 -2.304896

# %%
# For getting a value explicitly
df.iloc[1,1]
# Out:
# np.float64(-0.5202620512074064)

# %%
# For getting fast access to a scalar (equivalent to the prior method)
df.iat[1,1]
# Out:
# np.float64(-0.5202620512074064)

# %% [markdown]
# ## Boolean Indexing

# %%
# Select rows where df.A is greater than 0
df[df['A']> 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841

# %%
# Selecting values from a DataFrame where a boolean condition is met:
df[df > 0]
# df[mask] keeps True values and replaces False with NaN.
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.533066       NaN       NaN
# 2013-01-02  0.636042       NaN       NaN       NaN
# 2013-01-03       NaN       NaN       NaN  0.343653
# 2013-01-04       NaN  0.861993       NaN  1.035000
# 2013-01-05       NaN  1.068879  0.271003  0.143423
# 2013-01-06       NaN       NaN       NaN       NaN

# %%
# Using isin() method for filtering
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.885893  0.533066 -0.516280 -2.769899    one
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841    one
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653    two
# 2013-01-04 -0.271781  0.861993 -1.076835  1.035000  three
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423   four
# 2013-01-06 -0.603570 -0.465219 -2.304896 -0.003780  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653   two
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423  four

# %% [markdown]
# ## Setting

# %% [markdown]
# ***Setting a new column automatically aligns the data by the indexes***

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6],index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01 -0.885893  0.533066 -0.516280 -2.769899  NaN
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841  1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653  2.0
# 2013-01-04 -0.271781  0.861993 -1.076835  1.035000  3.0
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423  4.0
# 2013-01-06 -0.603570 -0.465219 -2.304896 -0.003780  5.0

# %%
# Setting values by label
df.at[dates[0], "A"] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.533066 -0.516280 -2.769899  NaN
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841  1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653  2.0
# 2013-01-04 -0.271781  0.861993 -1.076835  1.035000  3.0
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423  4.0
# 2013-01-06 -0.603570 -0.465219 -2.304896 -0.003780  5.0

# %%
# Setting values by position:
df.iat[0, 1] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000 -0.516280 -2.769899  NaN
# 2013-01-02  0.636042 -0.520262 -0.210243 -1.030841  1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210  0.343653  2.0
# 2013-01-04 -0.271781  0.861993 -1.076835  1.035000  3.0
# 2013-01-05 -1.383353  1.068879  0.271003  0.143423  4.0
# 2013-01-06 -0.603570 -0.465219 -2.304896 -0.003780  5.0

# %%
# Setting by assigning with a NumPy array:
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.516280  5.0  NaN
# 2013-01-02  0.636042 -0.520262 -0.210243  5.0  1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210  5.0  2.0
# 2013-01-04 -0.271781  0.861993 -1.076835  5.0  3.0
# 2013-01-05 -1.383353  1.068879  0.271003  5.0  4.0
# 2013-01-06 -0.603570 -0.465219 -2.304896  5.0  5.0

# %%
# A where operation with setting:
df2 = df.copy()
df2[df2 > 0] = -df2

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.516280  5.0  NaN
# 2013-01-02  0.636042 -0.520262 -0.210243  5.0  1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210  5.0  2.0
# 2013-01-04 -0.271781  0.861993 -1.076835  5.0  3.0
# 2013-01-05 -1.383353  1.068879  0.271003  5.0  4.0
# 2013-01-06 -0.603570 -0.465219 -2.304896  5.0  5.0

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.516280 -5.0  NaN
# 2013-01-02 -0.636042 -0.520262 -0.210243 -5.0 -1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210 -5.0 -2.0
# 2013-01-04 -0.271781 -0.861993 -1.076835 -5.0 -3.0
# 2013-01-05 -1.383353 -1.068879 -0.271003 -5.0 -4.0
# 2013-01-06 -0.603570 -0.465219 -2.304896 -5.0 -5.0

# %% [markdown]
# ## Missing data

# %%
# np.nan represents missing data

# %%
# Reindexing allows you to change/add/delete the index on a specified axis.
# This returns a copy of the data

# %%
df1 = df.reindex(index=dates[0:5], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.516280  5.0  NaN  1.0
# 2013-01-02  0.636042 -0.520262 -0.210243  5.0  1.0  1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210  5.0  2.0  NaN
# 2013-01-04 -0.271781  0.861993 -1.076835  5.0  3.0  NaN
# 2013-01-05 -1.383353  1.068879  0.271003  5.0  4.0  NaN

# %%
# gets the boolean mask where values are nan:
pd.isna(df1)       # When checking scalars, list or mixed types
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True
# 2013-01-05  False  False  False  False  False   True

# %%
df1.isnull()      # When working with DataFrame/Series
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True
# 2013-01-05  False  False  False  False  False   True

# %%
# To drop any row that has missing data 
# df1.dropna()
df1.dropna(how='any')
# Out:
#                    A         B         C    D    F    E
# 2013-01-02  0.636042 -0.520262 -0.210243  5.0  1.0  1.0

# %%
# filling missing data
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.516280  5.0  5.0  1.0
# 2013-01-02  0.636042 -0.520262 -0.210243  5.0  1.0  1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210  5.0  2.0  5.0
# 2013-01-04 -0.271781  0.861993 -1.076835  5.0  3.0  5.0
# 2013-01-05 -1.383353  1.068879  0.271003  5.0  4.0  5.0

# %%
# gets the boolean mask where values are nan:
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True
# 2013-01-05  False  False  False  False  False   True

# %% [markdown]
# ## Operations

# %% [markdown]
# ### Stats

# %% [markdown]
# ***Operations in general exclude missing data.***

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.516280  5.0  NaN
# 2013-01-02  0.636042 -0.520262 -0.210243  5.0  1.0
# 2013-01-03 -0.599084 -3.222444 -0.556210  5.0  2.0
# 2013-01-04 -0.271781  0.861993 -1.076835  5.0  3.0
# 2013-01-05 -1.383353  1.068879  0.271003  5.0  4.0
# 2013-01-06 -0.603570 -0.465219 -2.304896  5.0  5.0

# %%
# Calculating the mean
df.mean()
# Out:
# A   -0.370291
# B   -0.379509
# C   -0.732243
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.120930
# 2013-01-02    1.181107
# 2013-01-03    0.524452
# 2013-01-04    1.502675
# 2013-01-05    1.791306
# 2013-01-06    1.325263
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.599084 -4.222444 -1.556210  4.0  1.0
# 2013-01-04 -3.271781 -2.138007 -4.076835  2.0  0.0
# 2013-01-05 -6.383353 -3.931121 -4.728997  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ### User defined functions

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -2.073630
# B    -2.125250
# C    -4.100564
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000  -52.247495  506.0    NaN
# 2013-01-02   64.367440  -52.650520  -21.276605  506.0  101.2
# 2013-01-03  -60.627294 -326.111301  -56.288472  506.0  202.4
# 2013-01-04  -27.504241   87.233666 -108.975724  506.0  303.6
# 2013-01-05 -139.995321  108.170513   27.425501  506.0  404.8
# 2013-01-06  -61.081319  -47.080178 -233.255452  506.0  506.0

# %% [markdown]
# ### Value Counts

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    0
# 1    3
# 2    1
# 3    3
# 4    5
# 5    2
# 6    2
# 7    3
# 8    6
# 9    6
# dtype: int32

# %%
s.value_counts()
# Out:
# 3    3
# 6    2
# 2    2
# 0    1
# 5    1
# 1    1
# Name: count, dtype: int64

# %% [markdown]
# ### String Mehtods

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Concat

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.793727 -0.295478  1.280257 -1.442081
# 1  1.847808 -0.583164 -1.507620 -1.218251
# 2  0.327597 -0.633125 -0.382366  1.114666
# 3  1.503676  0.698676 -0.429684  0.280604
# 4  1.305762 -2.105918  0.143991  1.156665
# 5  0.014203 -0.165157  1.672090  0.078340
# 6 -1.022572  0.476674 -0.990839  0.339614
# 7  1.378180  1.310947  0.461320  1.651878
# 8  1.335559 -2.141977 -0.038480 -0.838681
# 9  0.264817  0.190538 -1.654166  2.108121

# %%
# Break it into pieces
pieces= [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.793727 -0.295478  1.280257 -1.442081
# 1  1.847808 -0.583164 -1.507620 -1.218251
# 2  0.327597 -0.633125 -0.382366  1.114666
# 3  1.503676  0.698676 -0.429684  0.280604
# 4  1.305762 -2.105918  0.143991  1.156665
# 5  0.014203 -0.165157  1.672090  0.078340
# 6 -1.022572  0.476674 -0.990839  0.339614
# 7  1.378180  1.310947  0.461320  1.651878
# 8  1.335559 -2.141977 -0.038480 -0.838681
# 9  0.264817  0.190538 -1.654166  2.108121

# %% [markdown]
# ### Join

# %%
# merge() enables SQL style join types along specific columns.

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right)
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
# merge() on unique keys:

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Grouping

# %%
# Group by involving Splitting, Applying and Combining

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.503693  2.034077
# 1  bar    one  0.019915  0.302338
# 2  foo    two  1.214909  0.117932
# 3  bar  three  0.762504 -0.164284
# 4  foo    two -1.903205  1.172425
# 5  bar    two -0.316201  0.268495
# 6  foo    one  0.202023  0.946392
# 7  foo  three  2.767101 -0.611141

# %%
# Grouping by column label
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar  0.466218  0.406549
# foo  1.777136  3.659685

# %%
# Grouping by multiple columns label forms MultiIndex
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.019915  0.302338
#     three  0.762504 -0.164284
#     two   -0.316201  0.268495
# foo one   -0.301670  2.980469
#     three  2.767101 -0.611141
#     two   -0.688295  1.290356

# %% [markdown]
# ## Reshaping

# %% [markdown]
# ### Stack

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.930158 -0.361464
#       two    -2.007068  0.868426
# baz   one     0.479889 -1.011710
#       two     0.685320  2.268330

# %%
# The stack() method “compresses” a level in the DataFrame’s columns

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -0.930158
#                B   -0.361464
#        two     A   -2.007068
#                B    0.868426
# baz    one     A    0.479889
#                B   -1.011710
#        two     A    0.685320
#                B    2.268330
# dtype: float64

# %%
# Inverse operation of stack() is unstack()
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.930158 -0.361464
#       two    -2.007068  0.868426
# baz   one     0.479889 -1.011710
#       two     0.685320  2.268330

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.930158 -2.007068
#       B -0.361464  0.868426
# baz   A  0.479889  0.685320
#       B -1.011710  2.268330

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.930158  0.479889
#        B -0.361464 -1.011710
# two    A -2.007068  0.685320
#        B  0.868426  2.268330

# %% [markdown]
# ## Pivot tables

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.199483  0.309523
# 1     one  B  foo -1.192474  0.636552
# 2     two  C  foo -1.584614  0.484978
# 3   three  A  bar  0.124766  0.377227
# 4     one  B  bar  1.443649 -0.452479
# 5     one  C  bar -0.753091  1.105957
# 6     two  A  foo -0.465369  0.055606
# 7   three  B  foo -0.643143  0.199976
# 8     one  C  foo  0.372774 -0.104370
# 9     one  A  bar  0.957794  0.433377
# 10    two  B  bar -1.381274  0.218905
# 11  three  C  bar -1.298990  0.250139

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.957794 -1.199483
#       B  1.443649 -1.192474
#       C -0.753091  0.372774
# three A  0.124766       NaN
#       B       NaN -0.643143
#       C -1.298990       NaN
# two   A       NaN -0.465369
#       B -1.381274       NaN
#       C       NaN -1.584614

# %% [markdown]
# ## Time series

# %% [markdown]
# ***To perform resampling operations during frequency conversions***

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    24526
# Freq: 5min, dtype: int32

# %%
# Series.tz_localize() localizes a time series to a time zone:

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06    2.674874
# 2012-03-07    1.196270
# 2012-03-08    0.593630
# 2012-03-09   -0.615459
# 2012-03-10   -0.086332
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    2.674874
# 2012-03-07 00:00:00+00:00    1.196270
# 2012-03-08 00:00:00+00:00    0.593630
# 2012-03-09 00:00:00+00:00   -0.615459
# 2012-03-10 00:00:00+00:00   -0.086332
# Freq: D, dtype: float64

# %%
# Series.tz_convert() converts a timezones aware time series to another time zone:

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00    2.674874
# 2012-03-06 19:00:00-05:00    1.196270
# 2012-03-07 19:00:00-05:00    0.593630
# 2012-03-08 19:00:00-05:00   -0.615459
# 2012-03-09 19:00:00-05:00   -0.086332
# Freq: D, dtype: float64

# %%
# Adding a non-fixed duration (BusinessDay) to a time series:

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## Categoricals

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
# Converting the raw grades to a categorical data type
df["grade"] = df["raw_grade"].astype("category")

# %%
df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# Renaming the categories to more meaningful names
new_categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
# Reorder the categories and simultaneously add the missing categories 
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df['grade']
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
# Sorting as per order in the categories
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
# Grouping by a categorical column with observed = False

# %%
df.groupby("grade", observed = False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
# The plot.close method is used to close a figure window

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot();

# %%
# plot() plots all columns:

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

# %%
df = df.cumsum()

# %%
plt.figure();

# %%
df.plot();

# %%
plt.legend(loc='best');
# Out:
# C:\Users\ashis\AppData\Local\Temp\ipykernel_14992\619983986.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best');

# %% [markdown]
# ## Importing and exporting data

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

# %%
df.to_csv("foo.csv")

# %%
# To read csv file
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  0  2  3  4  3
# 1           1  2  3  4  4  1
# 2           2  4  2  3  0  0
# 3           3  3  1  2  2  1
# 4           4  3  4  1  2  3
# 5           5  4  1  2  0  1
# 6           6  4  4  0  1  2
# 7           7  3  0  4  2  0
# 8           8  3  0  2  2  1
# 9           9  2  1  3  4  0

# %% [markdown]
# ## Parduet

# %%
df.to_parquet("foo.parquet")

# %%
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  0  2  3  4  3
# 1  2  3  4  4  1
# 2  4  2  3  0  0
# 3  3  1  2  2  1
# 4  3  4  1  2  3
# 5  4  1  2  0  1
# 6  4  4  0  1  2
# 7  3  0  4  2  0
# 8  3  0  2  2  1
# 9  2  1  3  4  0

# %% [markdown]
# ## Excel

# %%
# Writing to an excel file
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
# Reading to an excel file 
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  0  2  3  4  3
# 1           1  2  3  4  4  1
# 2           2  4  2  3  0  0
# 3           3  3  1  2  2  1
# 4           4  3  4  1  2  3
# 5           5  4  1  2  0  1
# 6           6  4  4  0  1  2
# 7           7  3  0  4  2  0
# 8           8  3  0  2  2  1
# 9           9  2  1  3  4  0
