# %%
print("Hellow World!! Welcome to Python course")
# Out:
# Hellow World!! Welcome to Python course

# %%
print("Twinkle, twinkle, little star,\nHow I wonder what you are!")
# Out:
# Twinkle, twinkle, little star,
# How I wonder what you are!

# %%
name=input("What's your name")
height=float(input("Enter your height"))
is_student=bool(input("Are you a student"))

print(f"Your are {name} with height of {height}meters. You are a Student? {is_student}")
# Out:
# What's your name sdf
# Enter your height 234
# Are you a student zxc
# Your are sdf with height of 234.0meters. You are a Student? True

# %%
num='55'
print(f"Printing  the number: {int(num)}")
# Out:
# Printing  the number: 55

# %%
fav_food= input("Your favorite food")
print(f"Wow, I also like {fav_food}")
# Out:
# Your favorite food as
# Wow, I also like as

# %%
n1=int(input("Enter the first number"))
n2=int(input("Enter the second number"))

print(n1+n2)
print(n1-n2)
print(n1*n2)
print(n1/n2)
# Out:
# Enter the first number 12
# Enter the second number 4
# 16
# 8
# 48
# 3.0

# %%
print('Harry said, "Python is awesome!\nThis is on a new line.\nThis is a tab ->\t<-here')
# Out:
# Harry said, "Python is awesome!
# This is on a new line.
# This is a tab ->	<-here

# %%
num=int(input('Enter a number'))
print("Square of number is ", num*num)
print("Cube of number is ", num*num*num)
# Out:
# Enter a number 4
# Square of number is  16
# Cube of number is  64
